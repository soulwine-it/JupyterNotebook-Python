# %%
import cv2
image = cv2.imread('park.jpg')

#픽셀 수 및 이미지 크기 확인
print("이미지 형태:",image.shape)
print("이미지 크기:",image.size)

#이미지 Numpy 객체의 특정 픽셀을 가리킵니다
px = image[100, 100]

# B, G, R 순서로 출력됩니다.
# (단, Gray Scale인 경우에는 B,G,R로 구분되지 않습니다.)
print(px)

# R값만 출력하기
print(px[2])
# Out:
# 이미지 형태: (301, 540, 3)
# 이미지 크기: 487620
# [69 64 65]
# 65

# %%
import matplotlib.pyplot as plt
import time

image = cv2.imread('park.jpg')

start_time = time.time()
for i in range(0, 100):
    for j in range(0, 100):
        image[i, j] = [255, 255, 255]
print("---%s seconds ---" %(time.time() - start_time))

start_time = time.time()
image[0:100, 0:100] = [0, 0, 0]
print("---%s seconds ---" %(time.time() - start_time))

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show
# Out:
# ---0.009973764419555664 seconds ---
# ---0.0 seconds ---
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
image = cv2.imread('park.jpg')

#Numpy Slicing: R이 처리 가능
roi = image[50:200, 180:330]

# R이 단위로 이미지 복사하기
image[0:150, 0:150] = roi

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# OpenCV를 활용한 픽셀별 색상 다루기

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('park.jpg')
#B G R 중 R을 0으로 만든 것
image[:, :, 2] = 0

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
